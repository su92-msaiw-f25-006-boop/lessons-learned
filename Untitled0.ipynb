# %% [markdown]
# <a href="https://colab.research.google.com/github/su92-msaiw-f25-006-boop/lessons-learned/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Linear Regression Model**

# %% [markdown]
# **Import libraries**

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
